# %%
# There are 20 variants of the `count_islands` function,
# and each of the variants has a bug.
# Can you find all bugs by writing testcases?

# Edit the main function to run your own testcases.
# Two examples are provided.
def main():
  grid = [
  ' ##   ',
  '  ##  ',
  '      ',
  ' # ## ',
  ' # ###',
  '     #']
  run_test(grid)

  grid = [
    '   ',
    ' # ',
    '   '
  ]
  run_test(grid)

  # Type error
  grid = (
    '   ',
    ' # ',
    '   '
    )
  run_test(grid)

  # lower bound error
  grid = [
    ''
    ]
  run_test(grid)

  grid = [
  '######',
  '######',
  '######',
  '######',
  '######',
  '######',
  '######',
  '######',
  '######',
  '######']
  run_test(grid)

  grid = [
  ' ##   ',
  '   #  ',
  '      ',
  ' # ## ',
  ' # ###',
  '     #']
  run_test(grid)

  grid = [
  ' ##   ',
  '   #  ',
  '      ',
  '## ###',
  '## ###',
  '      ']
  run_test(grid)

  grid = [
  ' ##   ',
  '   #  ',
  '      ',
  '## ###',
  '## ###',
  ' #    ']
  run_test(grid)

  grid = [
  '',
  ' #    ',
  '   #  ',
  '    # ',
  '     #']
  run_test(grid)

  grid = [
  '#     ',
  '      ',
  '      ',
  '      ',
  '      ',
  '     #']
  run_test(grid)

  grid = [
  '#     ',
  '      ',
  '  llll',
  '      ',
  '      ',
  '     #']
  run_test(grid)

  grid = [
  '#                                       ']
  run_test(grid)

  grid = ['#']
  run_test(grid)

  grid = ['#']
  run_test(grid)

# %%
# Challenge your own assumptions.
# Maybe this function doesn't do exactly what you think ;)
def count_islands(grid):
  # Verify grid is valid
  if type(grid) != list or len(set(map(len, grid))) != 1:
    return None
  height = len(grid)
  width = len(grid[0])
  visited = set()
  island_count = 0
  for base_row in range(height):
    for base_col in range(width):
      if (grid[base_row][base_col] == '#' and
          (base_row, base_col) not in visited):
        # Found a new island
        island_count += 1
        visited.add((base_row, base_col))
        stack = [(base_row, base_col)]
        while stack:
          # Perform a BFS to find all cells in the island
          row, col = stack.pop()
          # Hint: the next 4 lines are important.
          for diff_row in (-1, 0, 1):
            for diff_col in (-1, 0, 1):
              neighbor_row = (row + diff_row) % height
              neighbor_col = (col + diff_col) % width
              if ((neighbor_row, neighbor_col) not in visited and
                  grid[neighbor_row][neighbor_col] == '#'):
                # Add valid neighbor to the visit stack
                stack.append((neighbor_row, neighbor_col))
                # Mark neighbor as visited
                visited.add((neighbor_row, neighbor_col))
  return island_count

# "encrypted" source code, don't look inside!
import base64, zlib
FUNCTIONS = '''...'''
run_test=lambda x:None # This is just to make error-checking nicer
#exec(zlib.decompress(base64.b64decode(FUNCTIONS)))

# print the decoded source code in a readable format
print(zlib.decompress(base64.b64decode(FUNCTIONS)).decode())

# main()
# Out:
# def badfunc1(grid):
#   # Verify grid is valid
#   if type(grid) != list or len(set(map(len, grid))) != 1:
#     return None
#   height = len(grid)
#   width = len(grid[0])
#   island_count = 0
#   for r in range(height):
#     for c in range(width):
#       if grid[r][c] != '#':
#         continue
#       newisland = 1
#       for dr, dc in ((0, -1), (-1, -1), (-1, 0), (-1, 1)):
#         if grid[(r+dr) % height][(c+dc) % width] == '#':
#           newisland = 0
#       island_count += newisland
#   return island_count
#
# def badfunc2(grid):
#   # Verify grid is valid
#   if type(grid) != list or len(set(map(len, grid))) != 1:
#     return None
#   height = len(grid)
#   width = len(grid[0])
#   visited = set()
#   island_count = 0
#   for base_row in range(height):
#     for base_col in range(width):
#       if (grid[base_row][base_col] == '#' and
#           (base_row, base_col) not in visited):
#         # Found a new island
#         island_count += 1
#         visited.add((base_row, base_col))
#         stack = [(base_row, base_col)]
#         while stack:
#           # Perform a BFS to find all cells in the island
#           row, col = stack.pop()
#           for diff_row, diff_col in ((1, 0), (-1, 0), (0, 1), (0, -1)):
#             neighbor_row = (row + diff_row) % height
#             neighbor_col = (col + diff_col) % width
#             if ((neighbor_row, neighbor_col) not in visited and
#                 grid[neighbor_row][neighbor_col] == '#'):
#               # Add valid neighbor to the visit stack
#               stack.append((neighbor_row, neighbor_col))
#               # Mark neighbor as visited
#               visited.add((neighbor_row, neighbor_col))
#   return island_count
#
# def badfunc3(grid):
#   # Verify grid is valid
#   if type(grid) != list or len(set(map(len, grid))) != 1:
#     return None
#   height = len(grid)
#   width = len(grid[0])
#   visited = set()
#   island_count = 0
#   for base_row in range(height):
#     for base_col in range(width):
#       if (grid[base_row][base_col] != ' ' and
#           (base_row, base_col) not in visited):
#         # Found a new island
#         island_count += 1
#         visited.add((base_row, base_col))
#         stack = [(base_row, base_col)]
#         while stack:
#           # Perform a BFS to find all cells in the island
#           row, col = stack.pop()
#           for diff_row in (-1, 0, 1):
#             for diff_col in (-1, 0, 1):
#               neighbor_row = (row + diff_row) % height
#               neighbor_col = (col + diff_col) % width
#               if ((neighbor_row, neighbor_col) not in visited and
#                   grid[neighbor_row][neighbor_col] != ' '):
#                 # Add valid neighbor to the visit stack
#                 stack.append((neighbor_row, neighbor_col))
#                 # Mark neighbor as visited
#                 visited.add((neighbor_row, neighbor_col))
#   return island_count
#
# def badfunc4(grid):
#   # Verify grid is valid
#   if type(grid) != list:
#     return None
#   height = len(grid)
#   width = len(grid[0])
#   visited = set()
#   island_count = 0
#   for base_row in range(height):
#     for base_col in range(width):
#       if (grid[base_row][base_col] == '#' and
#           (base_row, base_col) not in visited):
#         # Found a new island
#         island_count += 1
#         visited.add((base_row, base_col))
#         stack = [(base_row, base_col)]
#         while stack:
#           # Perform a BFS to find all cells in the island
#           row, col = stack.pop()
#           for diff_row in (-1, 0, 1):
#             for diff_col in (-1, 0, 1):
#               neighbor_row = (row + diff_row) % height
#               neighbor_col = (col + diff_col) % width
#               if ((neighbor_row, neighbor_col) not in visited and
#                   grid[neighbor_row][neighbor_col] == '#'):
#                 # Add valid neighbor to the visit stack
#                 stack.append((neighbor_row, neighbor_col))
#                 # Mark neighbor as visited
#                 visited.add((neighbor_row, neighbor_col))
#   return island_count
#
# def badfunc5(grid):
#   height = len(grid)
#   width = len(grid[0])
#   visited = set()
#   island_count = 0
#   for base_row in range(height):
#     for base_col in range(width):
#       if (grid[base_row][base_col] == '#' and
#           (base_row, base_col) not in visited):
#         # Found a new island
#         island_count += 1
#         visited.add((base_row, base_col))
#         stack = [(base_row, base_col)]
#         while stack:
#           # Perform a BFS to find all cells in the island
#           row, col = stack.pop()
#           for diff_row in (-1, 0, 1):
#             for diff_col in (-1, 0, 1):
#               neighbor_row = (row + diff_row) % height
#               neighbor_col = (col + diff_col) % width
#               if ((neighbor_row, neighbor_col) not in visited and
#                   grid[neighbor_row][neighbor_col] == '#'):
#                 # Add valid neighbor to the visit stack
#                 stack.append((neighbor_row, neighbor_col))
#                 # Mark neighbor as visited
#                 visited.add((neighbor_row, neighbor_col))
#   return island_count
#
# def badfunc6(grid):
#   # Verify grid is valid
#   if type(grid) != list or len(set(map(len, grid))) != 1:
#     return None
#   height = len(grid)
#   width = len(grid[0])
#   visited = set()
#   island_count = 0
#   for base_row in range(height):
#     for base_col in range(width):
#       if (grid[base_row][base_col] == '#' and
#           (base_row, base_col) not in visited):
#         # Found a new island
#         island_count += 1
#         visited.add((base_row, base_col))
#         stack = [(base_row, base_col)]
#         while stack:
#           # Perform a BFS to find all cells in the island
#           row, col = stack.pop()
#           for diff_row in (-1, 0, 1):
#             for diff_col in (-1, 0, 1):
#               neighbor_row = row + diff_row
#               neighbor_col = col + diff_col
#               if not 0 <= neighbor_row < height:
#                 continue
#               if not 0 <= neighbor_col < width:
#                 continue
#               if ((neighbor_row, neighbor_col) not in visited and
#                   grid[neighbor_row][neighbor_col] == '#'):
#                 # Add valid neighbor to the visit stack
#                 stack.append((neighbor_row, neighbor_col))
#                 # Mark neighbor as visited
#                 visited.add((neighbor_row, neighbor_col))
#   return island_count
#
# def badfunc7(grid):
#   # Verify grid is valid
#   if type(grid) != list or len(set(map(len, grid))) != 1:
#     return None
#   height = len(grid)
#   width = len(grid[0])
#   visited = set()
#   island_count = 0
#
#   def bfs(grid, visited, r, c):
#     if (r, c) in visited or grid[r][c] != '#':
#       return
#     visited.add((r,c))
#     for diff_row in (-1, 0, 1):
#       for diff_col in (-1, 0, 1):
#         neighbor_row = (r + diff_row) % height
#         neighbor_col = (c + diff_col) % width
#         bfs(grid, visited, neighbor_row, neighbor_col)
#
#   for base_row in range(height):
#     for base_col in range(width):
#       if (grid[base_row][base_col] == '#' and
#           (base_row, base_col) not in visited):
#         # Found a new island
#         island_count += 1
#         bfs(grid, visited, base_row, base_col)
#   return island_count
#
# def badfunc8(grid):
#   # Verify grid is valid
#   if type(grid) != list or len(set(map(len, grid))) != 1:
#     return None
#   height = len(grid)
#   width = len(grid[0])
#   visited = set()
#   island_count = 0
#   for base_row in range(height-1):
#     for base_col in range(width):
#       if (grid[base_row][base_col] == '#' and
#           (base_row, base_col) not in visited):
#         # Found a new island
#         island_count += 1
#         visited.add((base_row, base_col))
#         stack = [(base_row, base_col)]
#         while stack:
#           # Perform a BFS to find all cells in the island
#           row, col = stack.pop()
#           for diff_row in (-1, 0, 1):
#             for diff_col in (-1, 0, 1):
#               neighbor_row = (row + diff_row) % height
#               neighbor_col = (col + diff_col) % width
#               if ((neighbor_row, neighbor_col) not in visited and
#                   grid[neighbor_row][neighbor_col] == '#'):
#                 # Add valid neighbor to the visit stack
#                 stack.append((neighbor_row, neighbor_col))
#                 # Mark neighbor as visited
#                 visited.add((neighbor_row, neighbor_col))
#   return island_count
#
# def badfunc9(grid):
#   # Verify grid is valid
#   if type(grid) != list or len(set(map(len, grid))) != 1:
#     return None
#   height = len(grid)
#   width = len(grid[0])
#   visited = set()
#   island_count = 0
#   for base_row in range(1, height):
#     for base_col in range(width):
#       if (grid[base_row][base_col] == '#' and
#           (base_row, base_col) not in visited):
#         # Found a new island
#         island_count += 1
#         visited.add((base_row, base_col))
#         stack = [(base_row, base_col)]
#         while stack:
#           # Perform a BFS to find all cells in the island
#           row, col = stack.pop()
#           for diff_row in (-1, 0, 1):
#             for diff_col in (-1, 0, 1):
#               neighbor_row = (row + diff_row) % height
#               neighbor_col = (col + diff_col) % width
#               if ((neighbor_row, neighbor_col) not in visited and
#                   grid[neighbor_row][neighbor_col] == '#'):
#                 # Add valid neighbor to the visit stack
#                 stack.append((neighbor_row, neighbor_col))
#                 # Mark neighbor as visited
#                 visited.add((neighbor_row, neighbor_col))
#   return island_count
#
# def badfunc10(grid):
#   # Verify grid is valid
#   if type(grid) != list or len(set(map(len, grid))) != 1:
#     return None
#   height = len(grid)
#   width = len(grid[0])
#   visited = set()
#   island_count = 0
#   for base_row in range(height):
#     for base_col in range(width-1):
#       if (grid[base_row][base_col] == '#' and
#           (base_row, base_col) not in visited):
#         # Found a new island
#         island_count += 1
#         visited.add((base_row, base_col))
#         stack = [(base_row, base_col)]
#         while stack:
#           # Perform a BFS to find all cells in the island
#           row, col = stack.pop()
#           for diff_row in (-1, 0, 1):
#             for diff_col in (-1, 0, 1):
#               neighbor_row = (row + diff_row) % height
#               neighbor_col = (col + diff_col) % width
#               if ((neighbor_row, neighbor_col) not in visited and
#                   grid[neighbor_row][neighbor_col] == '#'):
#                 # Add valid neighbor to the visit stack
#                 stack.append((neighbor_row, neighbor_col))
#                 # Mark neighbor as visited
#                 visited.add((neighbor_row, neighbor_col))
#   return island_count
#
# def badfunc11(grid):
#   # Verify grid is valid
#   if type(grid) != list or len(set(map(len, grid))) != 1:
#     return None
#   height = len(grid)
#   width = len(grid[0])
#   visited = set()
#   island_count = 0
#   for base_row in range(height):
#     for base_col in range(1, width):
#       if (grid[base_row][base_col] == '#' and
#           (base_row, base_col) not in visited):
#         # Found a new island
#         island_count += 1
#         visited.add((base_row, base_col))
#         stack = [(base_row, base_col)]
#         while stack:
#           # Perform a BFS to find all cells in the island
#           row, col = stack.pop()
#           for diff_row in (-1, 0, 1):
#             for diff_col in (-1, 0, 1):
#               neighbor_row = (row + diff_row) % height
#               neighbor_col = (col + diff_col) % width
#               if ((neighbor_row, neighbor_col) not in visited and
#                   grid[neighbor_row][neighbor_col] == '#'):
#                 # Add valid neighbor to the visit stack
#                 stack.append((neighbor_row, neighbor_col))
#                 # Mark neighbor as visited
#                 visited.add((neighbor_row, neighbor_col))
#   return island_count
#
# def badfunc12(grid):
#   # Verify grid is valid
#   if type(grid) != list or len(set(map(len, grid))) != 1:
#     return None
#   height = len(grid)
#   width = len(grid[0])
#   visited = set()
#   island_count = 0
#   for base_row in range(height):
#     for base_col in range(width):
#       if (grid[base_row][base_col] == '#' and
#           (base_row, base_col) not in visited):
#         # Found a new island
#         island_count += 1
#         visited.add((base_row, base_col))
#         stack = [(base_row, base_col)]
#         while stack:
#           # Perform a BFS to find all cells in the island
#           row, col = stack.pop()
#           for diff_row in (-1, 0, 1):
#             for diff_col in (-1, 0, 1):
#               neighbor_row = (row + diff_row) % (height-1)
#               neighbor_col = (col + diff_col) % (width-1)
#               if ((neighbor_row, neighbor_col) not in visited and
#                   grid[neighbor_row][neighbor_col] == '#'):
#                 # Add valid neighbor to the visit stack
#                 stack.append((neighbor_row, neighbor_col))
#                 # Mark neighbor as visited
#                 visited.add((neighbor_row, neighbor_col))
#   return island_count
#
# def badfunc13(grid):
#   # Verify grid is valid
#   if type(grid) != list or len(set(map(len, grid))) != 1:
#     return None
#   height = len(grid[0])
#   width = len(grid)
#   visited = set()
#   island_count = 0
#   for base_row in range(height):
#     for base_col in range(width):
#       if (grid[base_row][base_col] == '#' and
#           (base_row, base_col) not in visited):
#         # Found a new island
#         island_count += 1
#         visited.add((base_row, base_col))
#         stack = [(base_row, base_col)]
#         while stack:
#           # Perform a BFS to find all cells in the island
#           row, col = stack.pop()
#           for diff_row in (-1, 0, 1):
#             for diff_col in (-1, 0, 1):
#               neighbor_row = (row + diff_row) % height
#               neighbor_col = (col + diff_col) % width
#               if ((neighbor_row, neighbor_col) not in visited and
#                   grid[neighbor_row][neighbor_col] == '#'):
#                 # Add valid neighbor to the visit stack
#                 stack.append((neighbor_row, neighbor_col))
#                 # Mark neighbor as visited
#                 visited.add((neighbor_row, neighbor_col))
#   return island_count
#
# def badfunc14(grid):
#   if type(grid) != list or len(set(map(len, grid))) != 1:
#     return None
#   return 1+''.join(grid).count('#')//6
#
# def badfunc15(grid):
#   # Verify grid is valid
#   if type(grid) != list or len(set(map(len, grid))) != 1:
#     return None
#   height = len(grid)
#   width = len(grid[0])
#   visited = set()
#   island_count = 0
#   for base_row in range(height):
#     for base_col in range(width):
#       if (grid[base_row][base_col] == '#' and
#           (base_row, base_col) not in visited):
#         # Found a new island
#         island_count += 1
#         visited.add((base_row, base_col))
#         stack = [(base_row, base_col)]
#         while stack:
#           # Perform a BFS to find all cells in the island
#           row, col = stack.pop()
#           for diff_row in (-1, 1):
#             for diff_col in (-1, 0, 1):
#               neighbor_row = (row + diff_row) % height
#               neighbor_col = (col + diff_col) % width
#               if ((neighbor_row, neighbor_col) not in visited and
#                   grid[neighbor_row][neighbor_col] == '#'):
#                 # Add valid neighbor to the visit stack
#                 stack.append((neighbor_row, neighbor_col))
#                 # Mark neighbor as visited
#                 visited.add((neighbor_row, neighbor_col))
#   return island_count
#
# def badfunc16(grid):
#   # Verify grid is valid
#   if type(grid) != list or len(set(map(len, grid))) != 1:
#     return None
#   height = len(grid)
#   width = len(grid[0])
#   visited = set()
#   island_count = 0
#   for base_row in range(height):
#     for base_col in range(width):
#       if (grid[base_row][base_col] == '#' and
#           (base_row, base_col) not in visited):
#         # Found a new island
#         island_count += 1
#         visited.add((base_row, base_col))
#         stack = [(base_row, base_col)]
#         while stack:
#           # Perform a BFS to find all cells in the island
#           row, col = stack.pop()
#           for diff_row in (0, 1):
#             for diff_col in (-1, 0, 1):
#               neighbor_row = (row + diff_row) % height
#               neighbor_col = (col + diff_col) % width
#               if ((neighbor_row, neighbor_col) not in visited and
#                   grid[neighbor_row][neighbor_col] == '#'):
#                 # Add valid neighbor to the visit stack
#                 stack.append((neighbor_row, neighbor_col))
#                 # Mark neighbor as visited
#                 visited.add((neighbor_row, neighbor_col))
#   return island_count
#
# def badfunc17(grid):
#   # Verify grid is valid
#   if type(grid) != list or len(set(map(len, grid))) != 1:
#     return None
#   height = len(grid)
#   width = len(grid[0])
#   visited = set()
#   island_count = 0
#   for base_row in range(height):
#     for base_col in range(width):
#       if (grid[base_row][base_col] == '#' and
#           (base_row, base_col) not in visited):
#         # Found a new island
#         island_count += 1
#         visited.add((base_row, base_col))
#         stack = [(base_row, base_col)]
#         while stack:
#           # Perform a BFS to find all cells in the island
#           row, col = stack.pop()
#           for diff_row in (-1, 0, 1):
#             for diff_col in (0, 1):
#               neighbor_row = (row + diff_row) % height
#               neighbor_col = (col + diff_col) % width
#               if ((neighbor_row, neighbor_col) not in visited and
#                   grid[neighbor_row][neighbor_col] == '#'):
#                 # Add valid neighbor to the visit stack
#                 stack.append((neighbor_row, neighbor_col))
#                 # Mark neighbor as visited
#                 visited.add((neighbor_row, neighbor_col))
#   return island_count
#
# def badfunc18(grid):
#   # Verify grid is valid
#   if type(grid) != list or len(set(map(len, grid))) != 1:
#     return None
#   height = len(grid)
#   width = len(grid[0])
#   visited = set()
#   island_count = 0
#   for base_row in range(height):
#     for base_col in range(width):
#       if (grid[base_row][base_col] == '#' and
#           (base_row, base_col) not in visited):
#         # Found a new island
#         island_count += 1
#
#         rlimit = base_col
#         llimit = base_col
#         while grid[base_row][(rlimit+1)%width] == '#' and (rlimit+1)%width != llimit:
#           rlimit = (rlimit+1)%width
#
#         i = llimit
#         while i != (rlimit+1)%width:
#           visited.add((base_row, i))
#           i = (i+1) % width
#         for row in range(base_row + 1, height):
#
#           # Spread limits apart by 1 (diagonals)
#           if llimit != (rlimit+1)%width:
#             llimit = (llimit-1)%width
#           if llimit != (rlimit+1)%width:
#             rlimit = (rlimit+1)%width
#
#           if grid[row][llimit] == '#':
#             while (llimit-1)%width != rlimit and grid[row][(llimit-1)%width] == '#':
#               llimit = (llimit-1)%width
#           if grid[row][rlimit] == '#':
#             while (rlimit+1)%width != llimit and grid[row][(rlimit+1)%width] == '#':
#               rlimit = (rlimit+1)%width
#
#           keepgoing = False
#           if grid[row][llimit] == '#':
#             keepgoing = True
#           visited.add((row, llimit))
#           i = (llimit+1)%width
#           while i != (rlimit+1)%width:
#             if grid[row][i] == '#':
#               keepgoing = True
#             visited.add((row, i))
#             i = (i+1) % width
#           if not keepgoing:
#             break
#           while grid[row][llimit] != '#':
#             llimit = (llimit+1)%width
#           while grid[row][rlimit] != '#':
#             rlimit = (rlimit-1)%width
#   return island_count
#
# def badfunc19(grid):
#   # Verify grid is valid
#   if type(grid) != list or len(set(map(len, grid))) != 1:
#     return None
#   height = len(grid)
#   width = len(grid[0])
#   visited = set()
#   island_count = 0
#   for base_col in range(width):
#     for base_row in range(height):
#       if (grid[base_row][base_col] == '#' and
#           (base_row, base_col) not in visited):
#         # Found a new island
#         island_count += 1
#
#         rlimit = base_row
#         llimit = base_row
#         while grid[(rlimit+1)%height][base_col] == '#' and (rlimit+1)%height != llimit:
#           rlimit = (rlimit+1)%height
#
#         i = llimit
#         while i != (rlimit+1)%height:
#           visited.add((i, base_col))
#           i = (i+1) % height
#         for col in range(base_col + 1, width):
#
#           # Spread limits apart by 1 (diagonals)
#           if llimit != (rlimit+1)%height:
#             llimit = (llimit-1)%height
#           if llimit != (rlimit+1)%height:
#             rlimit = (rlimit+1)%height
#
#           if grid[llimit][col] == '#':
#             while (llimit-1)%height != rlimit and grid[(llimit-1)%height][col] == '#':
#               llimit = (llimit-1)%height
#           if grid[rlimit][col] == '#':
#             while (rlimit+1)%height != llimit and grid[(rlimit+1)%height][col] == '#':
#               rlimit = (rlimit+1)%height
#
#           keepgoing = False
#           if grid[llimit][col] == '#':
#             keepgoing = True
#           visited.add((llimit, col))
#           i = (llimit+1)%height
#           while i != (rlimit+1)%height:
#             if grid[i][col] == '#':
#               keepgoing = True
#             visited.add((i, col))
#             i = (i+1) % height
#           if not keepgoing:
#             break
#           while grid[llimit][col] != '#':
#             llimit = (llimit+1)%height
#           while grid[rlimit][col] != '#':
#             rlimit = (rlimit-1)%height
#   return island_count
#
# def badfunc20(grid):
#   # Verify grid is valid
#   if type(grid) != list or len(set(map(len, grid))) != 1:
#     return None
#   height = len(grid)
#   width = len(grid[0])
#   visited = set()
#   island_count = 0
#   for base_row in range(height):
#     for base_col in range(width):
#       if (grid[base_row][base_col] == '#' and
#           (base_row, base_col) not in visited):
#         # Found a new island
#         island_count += 1
#         visited.add((base_row, base_col))
#         stack = [(base_row, base_col)]
#         while stack:
#           # Perform a BFS to find all cells in the island
#           row, col = stack.pop()
#           for diff_row in (-1, 0, 1):
#             for diff_col in (-1, 0, 1):
#               neighbor_row = row + diff_row
#               while neighbor_row >= height:
#                 neighbor_row -= height
#               neighbor_col = col + diff_col
#               while neighbor_col >= width:
#                 neighbor_col -= width
#               if ((neighbor_row, neighbor_col) not in visited and
#                   grid[neighbor_row][neighbor_col] == '#'):
#                 # Add valid neighbor to the visit stack
#                 stack.append((neighbor_row, neighbor_col))
#                 # Mark neighbor as visited
#                 visited.add((neighbor_row, neighbor_col))
#   return island_count
#
#
# func_list = [badfunc1, badfunc2, badfunc3, badfunc4, badfunc5, badfunc6, badfunc7, badfunc8, badfunc9, badfunc10, badfunc11, badfunc12, badfunc13, badfunc14, badfunc15, badfunc16, badfunc17, badfunc18, badfunc19, badfunc20]
# killed_total = set()
#
# def run_test(grid):
#   print('='*50)
#   print('Running test... ', end='')
#   try:
#     expected_result = count_islands(grid)
#   except:
#     expected_result = None
#
#   print(f'Expected result: {expected_result}')
#
#   killed_bugs = []
#   for i, bugfunc in enumerate(func_list, start=1):
#     try:
#       result = bugfunc(grid)
#     except:
#       result = None
#     if result != expected_result:
#       killed_bugs.append(i)
#       print(f'[+] Bug caught! Function {i} returned {result}')
#
#   killed_total.update(killed_bugs)
#   bugs_left = sorted(set(range(1, len(func_list)+1)) - killed_total)
#   print(f'Bugs remaining: {bugs_left}')
#   print(f'>>>> Total score: {len(killed_total)}/{len(func_list)}.')

# %%
def func(x):
    return x + 1


def test_answer():
    assert func(4) == 5

# %%
import pytest

assert func(4) == 5
assert func(4) == 6
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[6], line 4
#       1 import pytest
#       3 assert func(4) == 5
# ----> 4 assert func(4) == 6
#
# AssertionError:
